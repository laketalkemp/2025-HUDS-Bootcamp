# %%
# Import the libraries
import numpy as np
import pandas as pd

# Set the path
path = "/Users/laketakemp/Desktop/Data/NBA Data 2010 2024/"

# Create the files
nba_season_data1 = path + "regular_season_box_scores_2010_2024_part_1.csv"
nba_season_data2 = path + "regular_season_box_scores_2010_2024_part_2.csv"
nba_season_data3 = path + "regular_season_box_scores_2010_2024_part_3.csv"

# %%
# Create dataframes
nba_season1 = pd.read_csv(nba_season_data1)
nba_season2 = pd.read_csv(nba_season_data2)
nba_season3 = pd.read_csv(nba_season_data3)

# %%
# Concatenate the files
all_data = nba_season1 + nba_season2 + nba_season3
nba_season_2010_2024 = pd.DataFrame(all_data)

# Check the join
nba_season_2010_2024.head()
# Out:
#              season_year  ... plusMinusPoints
# 0  2010-112010-112015-16  ...             7.0
# 1  2010-112010-112017-18  ...             4.0
# 2  2010-112011-122012-13  ...           -11.0
# 3  2010-112010-112013-14  ...             2.0
# 4  2010-112010-112017-18  ...             3.0
#
# [5 rows x 34 columns]

# %%
# Check the join
nba_season_2010_2024.tail()
# Out:
#                   season_year  ... plusMinusPoints
# 141488  2010-112011-122023-24  ...            50.0
# 141489  2011-122013-142023-24  ...            -1.0
# 141490  2010-112015-162023-24  ...           -11.0
# 141491  2011-122013-142023-24  ...           -12.0
# 141492                    NaN  ...             NaN
#
# [5 rows x 34 columns]

# %%
# Write to csv file
nba_season_2010_2024.to_csv('/Users/laketakemp/Desktop/Data/NBA Data 2010 2024/NBASeason20102024.csv', index = False)
