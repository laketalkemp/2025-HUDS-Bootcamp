# %%
# Import the libraries
import numpy as np
import pandas as pd

# Set the path
path = "/Users/laketakemp/Desktop/Data/NBA Data 2010 2024/"

# Create the files
nba_season_data1 = path + "regular_season_box_scores_2010_2024_part_1.csv"
nba_season_data2 = path + "regular_season_box_scores_2010_2024_part_2.csv"
nba_season_data3 = path + "regular_season_box_scores_2010_2024_part_3.csv"

# %%
# Create dataframes
nba_season1 = pd.read_csv(nba_season_data1)
nba_season2 = pd.read_csv(nba_season_data2)
nba_season3 = pd.read_csv(nba_season_data3)

# %%
nba_season1.head()
# Out:
#   season_year   game_date    gameId  ... foulsPersonal  points plusMinusPoints
# 0     2010-11  2010-11-10  21000112  ...             0       0              -4
# 1     2010-11  2010-11-17  21000165  ...             0       0               0
# 2     2010-11  2010-11-27  21000237  ...             0       0               0
# 3     2010-11  2010-12-12  21000351  ...             0       0               0
# 4     2010-11  2010-10-29  21000020  ...             1       2               6
#
# [5 rows x 34 columns]

# %%
nba_season1.shape
# Out:
# (141493, 34)

# %%
nba_season2.head()
# Out:
#   season_year   game_date    gameId  ... foulsPersonal  points plusMinusPoints
# 0     2010-11  2010-12-11  21000347  ...             3      14              10
# 1     2010-11  2010-11-19  21000173  ...             3      19               0
# 2     2011-12  2012-03-18  21100667  ...             2      18              -6
# 3     2010-11  2010-12-22  21000429  ...             5      22              -3
# 4     2010-11  2011-02-22  21000840  ...             3       8               1
#
# [5 rows x 34 columns]

# %%
nba_season2.shape
# Out:
# (141493, 34)

# %%
nba_season3.head()
# Out:
#   season_year   game_date    gameId  ... foulsPersonal  points plusMinusPoints
# 0     2015-16  2016-02-25  21500857  ...             0       0               1
# 1     2017-18  2017-12-07  21700365  ...             0       2               4
# 2     2012-13  2012-12-31  21200456  ...             2      10              -5
# 3     2013-14  2013-12-29  21300450  ...             1       4               5
# 4     2017-18  2017-12-16  21700431  ...             2       3              -4
#
# [5 rows x 34 columns]

# %%
nba_season3.shape
# Out:
# (141492, 34)

# %%
# Concatenate the files
nba_season_2010_2024 = pd.concat([nba_season1, nba_season2, nba_season3], axis=0, join='outer', ignore_index=True)

# Check the join
nba_season_2010_2024.head()
# Out:
#   season_year   game_date    gameId  ... foulsPersonal  points plusMinusPoints
# 0     2010-11  2010-11-10  21000112  ...             0       0              -4
# 1     2010-11  2010-11-17  21000165  ...             0       0               0
# 2     2010-11  2010-11-27  21000237  ...             0       0               0
# 3     2010-11  2010-12-12  21000351  ...             0       0               0
# 4     2010-11  2010-10-29  21000020  ...             1       2               6
#
# [5 rows x 34 columns]

# %%
# Check the join
nba_season_2010_2024.tail()
# Out:
#        season_year   game_date  ...  points plusMinusPoints
# 424473     2023-24  2024-01-25  ...       0               0
# 424474     2023-24  2024-01-21  ...       0               0
# 424475     2023-24  2024-01-29  ...       0               0
# 424476     2023-24  2024-01-24  ...       0               3
# 424477     2023-24  2024-01-27  ...       0               0
#
# [5 rows x 34 columns]

# %%
# Write to csv file
nba_season_2010_2024.to_csv('/Users/laketakemp/Desktop/Data/NBA Data 2010 2024/NBASeason20102024.csv', index = False)
