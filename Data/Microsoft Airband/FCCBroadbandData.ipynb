# %%
import numpy as np
import pandas as pd
# Let's make sure pandas returns all the rows and columns for the dataframe
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Force pandas to display full numbers instead of scientific notation
#pd.options.display.float_format = '{:.6f}'.format

# Library to suppress warnings
import warnings
warnings.filterwarnings('ignore')


path = "/Users/laketakemp/Desktop/Data/Microsoft Airband/"

fixed_broadband = pd.read_csv(path + "bdc_us_fixed_broadband_summary_by_geography_D24_10jun2025.csv")
mobile_broadband = pd.read_csv(path + "bdc_us_mobile_broadband_summary_by_geography_D24_10jun2025.csv")
provider_summary = pd.read_csv(path + "bdc_us_provider_summary_by_geography_D24_10jun2025.csv")

# %%
mobile_broadband.head()
# Out:
#   area_data_type geography_type geography_id geography_desc    total_area  \
# 0          Total       National           99       National  9.754824e+06
# 1          Total          State           01        Alabama  1.370274e+05
# 2          Total          State           02         Alaska  1.846753e+06
# 3          Total          State           04        Arizona  2.573078e+05
# 4          Total          State           05       Arkansas  1.310934e+05
#
#    mobilebb_3g_area_st_pct  mobilebb_3g_area_iv_pct  mobilebb_4g_area_st_pct  \
# 0                 0.061412                 0.042772                 0.687893
# 1                 0.000000                 0.000000                 0.946387
# 2                 0.081332                 0.053745                 0.074291
# 3                 0.070936                 0.047557                 0.725504
# 4                 0.000000                 0.000000                 0.909323
#
# ...

# %%
provider_summary.head()
# Out:
#   geography_type geography_id           geography_desc        data_type  \
# 0     CBSA (MSA)        10100  Aberdeen, SD Micro Area  Fixed Broadband
# 1     CBSA (MSA)        10100  Aberdeen, SD Micro Area  Fixed Broadband
# 2     CBSA (MSA)        10100  Aberdeen, SD Micro Area  Fixed Broadband
# 3     CBSA (MSA)        10100  Aberdeen, SD Micro Area  Fixed Broadband
# 4     CBSA (MSA)        10100  Aberdeen, SD Micro Area  Fixed Broadband
#
#    provider_id  res_st_pct  bus_iv_pct
# 0       130077      0.0000      0.1291
# 1       130228      0.5622      0.5622
# 2       130403      0.1278      0.1475
# 3       130405      0.0042      0.0042
# 4       130627      1.0000      1.0000

# %%
fixed_broadband.head()
# Out:
#   area_data_type geography_type geography_id geography_desc  \
# 0          Total       National           99       National
# 1          Total       National           99       National
# 2          Total       National           99       National
# 3          Total       National           99       National
# 4          Total       National           99       National
#
#   geography_desc_full  total_units biz_res       technology  speed_02_02  \
# 0            National    164620769       R   Any Technology     1.000000
# 1            National    164620769       B   Any Technology     1.000000
# 2            National    164620769       R        All Wired     0.942141
# 3            National    164620769       B        All Wired     0.829826
# 4            National    164620769       R  Any Terrestrial     0.978991
#
#    speed_10_1  speed_25_3  speed_100_20  speed_250_25  speed_1000_100
# 0    1.000000    1.000000      0.999915      0.913689        0.591365
# ...

# %%
fixed_broadband.tail()
# Out:
#        area_data_type geography_type geography_id geography_desc  \
# 623935          Rural     CBSA (MSA)        49820     Zapata, TX
# 623936          Rural     CBSA (MSA)        49820     Zapata, TX
# 623937          Rural     CBSA (MSA)        49820     Zapata, TX
# 623938          Rural     CBSA (MSA)        49820     Zapata, TX
# 623939          Rural     CBSA (MSA)        49820     Zapata, TX
#
#        geography_desc_full  total_units biz_res                 technology  \
# 623935          Zapata, TX         2642       B  Unlicensed Fixed Wireless
# 623936          Zapata, TX         2642       R    Licensed Fixed Wireless
# 623937          Zapata, TX         2642       B    Licensed Fixed Wireless
# 623938          Zapata, TX         2642       R                      Other
# 623939          Zapata, TX         2642       B                      Other
#
#         speed_02_02  speed_10_1  speed_25_3  speed_100_20  speed_250_25  \
# ...

# %%
fixed_broadband['geography_desc'].unique()
# Out:
# array(['National', 'Acoma Pueblo', 'Acoma Off-Reservation Trust Land',
#        ..., 'Yuma, AZ', 'Zanesville, OH', 'Zapata, TX'], dtype=object)

# %%
fixed_broadband.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 623940 entries, 0 to 623939
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   area_data_type       623940 non-null  object
#  1   geography_type       623940 non-null  object
#  2   geography_id         623940 non-null  object
#  3   geography_desc       623940 non-null  object
#  4   geography_desc_full  623940 non-null  object
#  5   total_units          623940 non-null  int64
#  6   biz_res              623940 non-null  object
#  7   technology           623940 non-null  object
#  8   speed_02_02          623940 non-null  float64
#  9   speed_10_1           623940 non-null  float64
#  10  speed_25_3           623940 non-null  float64
#  11  speed_100_20         623940 non-null  float64
#  12  speed_250_25         623940 non-null  float64
#  13  speed_1000_100       623940 non-null  float64
# dtypes: float64(6), int64(1), object(7)
# ...
